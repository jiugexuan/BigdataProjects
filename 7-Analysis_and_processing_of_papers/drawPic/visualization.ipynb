# %%
import pandas as pd
# import numpy as np
import matplotlib.pyplot as plt
import wordcloud
import random
import matplotlib.font_manager as fm

# %%
hotWord_all = pd.read_csv('CVPR/hotWords19-23_des.csv',header=None, names=['word', 'num'])

# %%
hotWord_all.info
# Out:
# <bound method DataFrame.info of            word   num
# 0      Learning  1799
# 1         Image   984
# 2            3D   813
# 3     Detection   731
# 4        Object   715
# ...         ...   ...
# 8213     iPLAN:     1
# 8214     iTAML:     1
# 8215      iVPF:     1
# 8216   solution     1
# 8217    Useful:     1
#
# [8218 rows x 2 columns]>

# %%
hotWord_dict = hotWord_all.set_index(['word'])['num'].to_dict()

# %%
def random_color_func(word=None, font_size=None, position=None,  orientation=None, font_path=None, random_state=None):
        h  = random.randint(120,250)
        s = int(100.0 * 255.0 / 255.0)
        l = int(100.0 * float(random.randint(60, 120)) / 255.0)
        return "hsl({}, {}%, {}%)".format(h, s, l)

# %%
wc = wordcloud.WordCloud(
    # font_path='TIMES.TTF',
    background_color='white',
    width=2000,height=1200,
    max_words=350,
    max_font_size=500,
    #color_func=random_color_func
)

# %%
# wc.rc('font',family='Times New Roman')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 wc.rc('font',family='Times New Roman')
#
# AttributeError: 'WordCloud' object has no attribute 'rc'

# %%
wc.generate_from_frequencies(hotWord_dict)

# %%
# wc.render("wordCloud.html")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 wc.render("wordCloud.html")
#
# AttributeError: 'WordCloud' object has no attribute 'render'

# %%
plt.imshow(wc)
plt.axis('off')
plt.savefig('hotwordcloud.png',dpi=600)
plt.show()
# plt.close()

# %%
fig = plt.figure(figsize=(14,6))
# YaHei = fm.FontProperties(fname='MSYH.TTC')
# TNR = fm.FontProperties(fname='TIMES.TTF')
YaHei = fm.FontProperties()
TNR = fm.FontProperties()
hotWordTop20 = []
hotWordTop20_num = []
stopword = ['via', 'Using']
for i, (word, num) in enumerate(hotWord_dict.items()):
    if word in stopword:
        continue
    plt.text(word, num+5, num, ha='center', va='bottom', fontsize=8, fontproperties=TNR)#+0.05 表示高于图0.0
    hotWordTop20.append(word)
    hotWordTop20_num.append(num)
    if len(hotWordTop20)==20:
        break

# plt.bar(hotWordTop20,hotWordTop20_num,color='rgby')
plt.bar(hotWordTop20,hotWordTop20_num,color=['r','g','b','y'])
plt.title('包含热点词汇的文章数',fontproperties=YaHei) # 标题
plt.xlabel('热点词汇',fontproperties=YaHei) # x轴标签
plt.xticks(rotation=-45)
plt.ylabel('文\n章\n数',fontproperties=YaHei,rotation='horizontal') # y轴标签
plt.savefig('top10Word.png',dpi=600)
# plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_5774/1137633263.py:24: UserWarning: Glyph 25991 (\N{CJK UNIFIED IDEOGRAPH-6587}) missing from current font.
#   plt.savefig('top10Word.png',dpi=600)
# /tmp/ipykernel_5774/1137633263.py:24: UserWarning: Glyph 31456 (\N{CJK UNIFIED IDEOGRAPH-7AE0}) missing from current font.
#   plt.savefig('top10Word.png',dpi=600)
# /tmp/ipykernel_5774/1137633263.py:24: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from current font.
#   plt.savefig('top10Word.png',dpi=600)
# /tmp/ipykernel_5774/1137633263.py:24: UserWarning: Glyph 21253 (\N{CJK UNIFIED IDEOGRAPH-5305}) missing from current font.
#   plt.savefig('top10Word.png',dpi=600)
# /tmp/ipykernel_5774/1137633263.py:24: UserWarning: Glyph 21547 (\N{CJK UNIFIED IDEOGRAPH-542B}) missing from current font.
#   plt.savefig('top10Word.png',dpi=600)
# /tmp/ipykernel_5774/1137633263.py:24: UserWarning: Glyph 28909 (\N{CJK UNIFIED IDEOGRAPH-70ED}) missing from current font.
#   plt.savefig('top10Word.png',dpi=600)
# /tmp/ipykernel_5774/1137633263.py:24: UserWarning: Glyph 28857 (\N{CJK UNIFIED IDEOGRAPH-70B9}) missing from current font.
#   plt.savefig('top10Word.png',dpi=600)
# /tmp/ipykernel_5774/1137633263.py:24: UserWarning: Glyph 35789 (\N{CJK UNIFIED IDEOGRAPH-8BCD}) missing from current font.
#   plt.savefig('top10Word.png',dpi=600)
# /tmp/ipykernel_5774/1137633263.py:24: UserWarning: Glyph 27719 (\N{CJK UNIFIED IDEOGRAPH-6C47}) missing from current font.
#   plt.savefig('top10Word.png',dpi=600)
# /tmp/ipykernel_5774/1137633263.py:24: UserWarning: Glyph 30340 (\N{CJK UNIFIED IDEOGRAPH-7684}) missing from current font.
#   plt.savefig('top10Word.png',dpi=600)
# /home/hadoop/1-Bigdata/code/7-Analysis_and_processing_of_papers/drawPic/venv/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 25991 (\N{CJK UNIFIED IDEOGRAPH-6587}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/hadoop/1-Bigdata/code/7-Analysis_and_processing_of_papers/drawPic/venv/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 31456 (\N{CJK UNIFIED IDEOGRAPH-7AE0}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/hadoop/1-Bigdata/code/7-Analysis_and_processing_of_papers/drawPic/venv/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/hadoop/1-Bigdata/code/7-Analysis_and_processing_of_papers/drawPic/venv/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 21253 (\N{CJK UNIFIED IDEOGRAPH-5305}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/hadoop/1-Bigdata/code/7-Analysis_and_processing_of_papers/drawPic/venv/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 21547 (\N{CJK UNIFIED IDEOGRAPH-542B}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/hadoop/1-Bigdata/code/7-Analysis_and_processing_of_papers/drawPic/venv/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 28909 (\N{CJK UNIFIED IDEOGRAPH-70ED}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/hadoop/1-Bigdata/code/7-Analysis_and_processing_of_papers/drawPic/venv/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 28857 (\N{CJK UNIFIED IDEOGRAPH-70B9}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/hadoop/1-Bigdata/code/7-Analysis_and_processing_of_papers/drawPic/venv/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 35789 (\N{CJK UNIFIED IDEOGRAPH-8BCD}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/hadoop/1-Bigdata/code/7-Analysis_and_processing_of_papers/drawPic/venv/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 27719 (\N{CJK UNIFIED IDEOGRAPH-6C47}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/hadoop/1-Bigdata/code/7-Analysis_and_processing_of_papers/drawPic/venv/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 30340 (\N{CJK UNIFIED IDEOGRAPH-7684}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
authors_all = pd.read_csv('CVPR/authors_all_DES.csv',header=None, names=['authors', 'num'])

# %%
authors_all.info
# Out:
# <bound method DataFrame.info of                              authors  num
# 0     Yang Liu,11\nAyan Kumar Bhunia    8
# 1                  Yi Li,7\nXiang Li    7
# 2        Sucheng Ren,6\nZhenyu Zhang    6
# 3      Daniel Barath,6\nYanchao Yang    6
# 4      Tianfei Zhou,6\nGengshan Yang    6
# ...                              ...  ...
# 3327        Zikai Zhang,1\nZipeng Xu    1
# 3328       Zitian Tang,1\nZiyan Yang    1
# 3329       Ziyun Zeng,1\nZizheng Que    1
# 3330  Zonghui Guo,1\nZuzana Kukelova    1
# 3331                        Tao Wang    1
#
# [3332 rows x 2 columns]>

# %%
authors_dict = authors_all.set_index(['authors'])['num'].to_dict()

# %%
fig2 = plt.figure(figsize=(12,8))
authorsTop20 = []
authorsTop20_num = []

for i, (author, num) in enumerate(authors_dict.items()):
    plt.text(num+1,author, num, ha='center', va='bottom', fontsize=8, fontproperties=TNR)#+0.05 表示高于图0.0
    authorsTop20.append(author)
    authorsTop20_num.append(num)
    if i==19:
        break

# plt.barh(authorsTop20[::-1],authorsTop20_num[::-1],color='rgb') # 从大到小画图
plt.barh(authorsTop20[::-1],authorsTop20_num[::-1],color=['r','g','b','y']) # 从大到小画图
plt.title('高产作者',fontproperties=YaHei) # 标题
plt.ylabel('作\n者\n名',fontproperties=YaHei,rotation='horizontal') # y轴标签
plt.xlabel('文章数',fontproperties=YaHei) # x轴标签
plt.savefig('top10authors.png',dpi=600, bbox_inches="tight")
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_5774/2801559455.py:17: UserWarning: Glyph 20316 (\N{CJK UNIFIED IDEOGRAPH-4F5C}) missing from current font.
#   plt.savefig('top10authors.png',dpi=600, bbox_inches="tight")
# /tmp/ipykernel_5774/2801559455.py:17: UserWarning: Glyph 32773 (\N{CJK UNIFIED IDEOGRAPH-8005}) missing from current font.
#   plt.savefig('top10authors.png',dpi=600, bbox_inches="tight")
# /tmp/ipykernel_5774/2801559455.py:17: UserWarning: Glyph 21517 (\N{CJK UNIFIED IDEOGRAPH-540D}) missing from current font.
#   plt.savefig('top10authors.png',dpi=600, bbox_inches="tight")
# /tmp/ipykernel_5774/2801559455.py:17: UserWarning: Glyph 39640 (\N{CJK UNIFIED IDEOGRAPH-9AD8}) missing from current font.
#   plt.savefig('top10authors.png',dpi=600, bbox_inches="tight")
# /tmp/ipykernel_5774/2801559455.py:17: UserWarning: Glyph 20135 (\N{CJK UNIFIED IDEOGRAPH-4EA7}) missing from current font.
#   plt.savefig('top10authors.png',dpi=600, bbox_inches="tight")
# /tmp/ipykernel_5774/2801559455.py:17: UserWarning: Glyph 25991 (\N{CJK UNIFIED IDEOGRAPH-6587}) missing from current font.
#   plt.savefig('top10authors.png',dpi=600, bbox_inches="tight")
# /tmp/ipykernel_5774/2801559455.py:17: UserWarning: Glyph 31456 (\N{CJK UNIFIED IDEOGRAPH-7AE0}) missing from current font.
#   plt.savefig('top10authors.png',dpi=600, bbox_inches="tight")
# /tmp/ipykernel_5774/2801559455.py:17: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from current font.
#   plt.savefig('top10authors.png',dpi=600, bbox_inches="tight")
# /home/hadoop/1-Bigdata/code/7-Analysis_and_processing_of_papers/drawPic/venv/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 20316 (\N{CJK UNIFIED IDEOGRAPH-4F5C}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/hadoop/1-Bigdata/code/7-Analysis_and_processing_of_papers/drawPic/venv/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 32773 (\N{CJK UNIFIED IDEOGRAPH-8005}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/hadoop/1-Bigdata/code/7-Analysis_and_processing_of_papers/drawPic/venv/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 21517 (\N{CJK UNIFIED IDEOGRAPH-540D}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/hadoop/1-Bigdata/code/7-Analysis_and_processing_of_papers/drawPic/venv/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 39640 (\N{CJK UNIFIED IDEOGRAPH-9AD8}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/hadoop/1-Bigdata/code/7-Analysis_and_processing_of_papers/drawPic/venv/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 20135 (\N{CJK UNIFIED IDEOGRAPH-4EA7}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/hadoop/1-Bigdata/code/7-Analysis_and_processing_of_papers/drawPic/venv/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 25991 (\N{CJK UNIFIED IDEOGRAPH-6587}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/hadoop/1-Bigdata/code/7-Analysis_and_processing_of_papers/drawPic/venv/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 31456 (\N{CJK UNIFIED IDEOGRAPH-7AE0}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/hadoop/1-Bigdata/code/7-Analysis_and_processing_of_papers/drawPic/venv/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

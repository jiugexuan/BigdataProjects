# %%
import os
abs_path = os.getcwd()

# %%
import pandas as pd
import matplotlib.pyplot as plt
#当python文件和csv文件路径不同时要修改运行路径
people_per_country = pd.read_csv(abs_path+"/people_per_country.csv", header=None, names=["country", "people"], index_col=0)
people_per_game = pd.read_csv(abs_path+"/people_per_Game.csv", header=None, names=["game", "people"], index_col=0)
total_per_country = pd.read_csv(abs_path+"/total_per_country.csv", header=None, names=["country", "total"], index_col=0)

# %%
people_per_country.plot.bar()
# Out:
# <Axes: xlabel='country'>

# %%
people_per_country.plot.pie(subplots=True, figsize=(15,15),rotatelabels=True,labeldistance=0.8,radius=0.9,fontsize=11)
# Out:
# array([<Axes: ylabel='people'>], dtype=object)

# %%
people_per_game.plot.bar()
# Out:
# <Axes: xlabel='game'>

# %%
people_per_game.plot.pie(subplots=True, figsize=(15,15),rotatelabels=True,labeldistance=0.8,radius=0.9,fontsize=11)
# Out:
# array([<Axes: ylabel='people'>], dtype=object)

# %%
total_per_country.plot.bar()
# Out:
# <Axes: xlabel='country'>

# %%
total_per_country.plot.pie(subplots=True, figsize=(15,15),rotatelabels=True,labeldistance=0.8,radius=0.9,fontsize=11)
# Out:
# array([<Axes: ylabel='total'>], dtype=object)
